# %%
using JLD2
using Plots

file_path = joinpath(dirname(@__FILE__), "..", "lossg.jld2")
plotg = JLD2.load(file_path)["lossg_vals"]
plot(plotg, title = "Generator Loss", linewidth=2, legend = false)

# %%
plotd = JLD2.load("lossd.jld2")["lossd_vals"]
plot(plotd, title = "Discriminator Loss", linewidth=3, legend = false)
# Out:
# UndefVarError: `JLD2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/Desktop - Peter’s MacBook Air/Harvard/2.5/PRISE/Project/MatchgateGAN/runnable/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:1
